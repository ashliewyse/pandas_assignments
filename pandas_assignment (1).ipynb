# %% [markdown]
# # Pandas Data Science Case Study
# This notebook follows along with the "Pandas for Data Science in 20 Minutes" tutorial.
# Dataset used: telco_churn.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("telco_churn.csv")

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %% [markdown]
# ## Dataset Dimensions
# The shape function shows the number of rows and columns.

# %%
df.shape
# Out:
# (3333, 20)

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# ## Dataset Information
# The info() function displays data types and non-null counts for each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3323 non-null   float64
#  7   Total day calls         3323 non-null   float64
#  8   Total day charge        3315 non-null   float64
#  9   Total eve minutes       3324 non-null   float64
#  10  Total eve calls         3325 non-null   float64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3332 non-null   float64
# ...

# %% [markdown]
# ## Summary Statistics
# The describe() function provides summary statistics for numerical columns.

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# ...

# %% [markdown]
# ## Missing Values
# Check for any missing data in each column.

# %%
df.isna().sum()
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %% [markdown]
# ## Churn Distribution
# Count how many customers churned versus did not churn.

# %%
df["Churn"].value_counts()
# Out:
# Churn
# False    2842
# True      483
# Name: count, dtype: int64

# %% [markdown]
# ## Average Metrics by Churn Status
# Compare average numerical values between churned and non-churned customers.

# %%
df.groupby("Churn").mean(numeric_only=True)
# Out:
#        Account length   Area code  Number vmail messages  Total day minutes  \
# Churn
# False      100.751232  437.003167               8.576003         175.172336
# True       102.664596  437.817805               5.115942         206.952599
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# Churn
# False       100.282992         29.774446         199.113444       100.073721
# True        101.432432         35.167375         212.327178       100.522822
#
#        Total eve charge  Total night minutes  Total night calls  \
# Churn
# False         16.918455           200.150422         100.073214
# True          18.054969           205.231677         100.399586
#
#        Total night charge  Total intl minutes  Total intl calls  \
# Churn
# False            9.006847           10.159606          4.527445
# True             9.235528           10.700000          4.163561
#
#        Total intl charge  Customer service calls
# Churn
# ...

# %% [markdown]
# ## Conclusion
#
# The dataset contains 3,333 customers and 20 features.
# Most customers did not churn (2,842 vs 483 who churned).
# On average, customers who churned tend to have higher total day minutes and charges compared to non-churned customers.
